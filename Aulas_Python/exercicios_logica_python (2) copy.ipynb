# %% [markdown]
# ## Nível Fácil
# 1. O que acontece quando você executa `bool("")`?

# %%
bool("")

# %% [markdown]
# 2. Analise a expressão: `5 > 3`

# %%
ex2 = 5 > 3
print(f"N1:{ex2}")~

# %% [markdown]
# 3. Analise: `10 == 20`

# %%
ex3 = 10 == 20
print(f"N2:{ex3}")

# %% [markdown]
# 4. O que `not True` retorna?

# %%
"""ex 4 = retorna o inverso not true == false"""

# %% [markdown]
# 5. Crie uma variável booleana `logado = True`.

# %%
logado = True

# %% [markdown]
# 6. Resultado de `(10 > 5) and (2 < 1)`

# %%
ex6 = (10 > 5) and (2 < 1)
print(f"Ex6:{ex6}")

# %% [markdown]
# 7. Avalie `(3 != 3) or (4 >= 2)`

# %%
ex7 = (3 != 3) or (4 >= 2)
print(f"Ex7:{ex7}")

# %% [markdown]
# 8. Explique como funciona o operador `or`.

# %%
"""Ex:8 variavel or determina se alguma das duas possibilidades e positivo"""

# %% [markdown]
# 9. Determine o valor da variável abaixo:
#
# ```python
# idade = 17
# tem_carteira = True
# pode_dirigir = (idade >= 18) and tem_carteira
# ```

# %%
"""EX9"""
idade = 17
tem_carteira = True
pode_dirigir = (idade > 18) and tem_carteira
print(pode_dirigir)

# %% [markdown]
# 10. Crie um código que verifique se uma pessoa pode comprar bebida (idade >= 18).

# %%
"""EX10"""
idade = 17
pode_beber = idade >= 18
print(f"Pode Beber:{pode_beber}")

# %% [markdown]
# 11. Explique passo a passo o resultado:
#
# ```python
# not ( (4 < 3 and True) or (10 == 10 and False) )
# ```

# %%
ex11 = not ((4 < 3 and True) or (10 == 10 and False))
print(ex11)
"""Aqui foi verificado se 4 < 3 = false and True ou seja se tornou = false as duas condicoes depois foi verificado que 10 == 10 = True and false = que se tornou false como as duas verificacoes foram falsas e temos o not nesta expresao foi invertido not (false) = True"""

# %% [markdown]
# 12. A expressão retorna True ou False?
#
# ```python
# (False or True) and (not (True and True))
# ```

# %%
ex12 = "Retorna False"

# %% [markdown]
# 13. Programa simples:
# - Receba duas entradas do usuário (“0” ou “1”)
# - Converta para booleano
# - Aplique AND e OR
# - Exiba os resultados

# %%
"""ex13"""

n1 = bool(input("Digite 0 ou 1:"))
print(n1)

"""AND = so e TRUE se os dois forem TRUE"""
"""OR = e True se pelomenos 1 for TRUE"""
